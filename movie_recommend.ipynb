# %%
import numpy as np
import pandas as pd
import json

# %%
# https://www.kaggle.com/rounakbanik/the-movies-dataset  -> dataset 

meta = pd.read_csv('./downloads/the-movies-dataset/movies_metadata.csv')
meta.head()
# Out:
# /Users/simdaebeom/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
meta = meta[['id','original_title','original_language','genres']]
#column 이름 id -> movieId로 바꾼다.
meta = meta.rename(columns={'id':'movieId'})
#영어로 된 영화만 추렸다.
meta = meta[meta['original_language']=='en']
meta.head()
# Out:
#      movieId original_title original_language  \
# 642    54285        삼공일 삼공이                ko
# 3901   25660    인정사정 볼 것 없다                ko
# 5392    8653              섬                ko
# 5550   37288       고양이를 부탁해                ko
# 5683   33251        Jibeuro                ko
#
#                                                  genres
# 642   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 3901  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 5392  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 5550                      [{'id': 18, 'name': 'Drama'}]
# 5683  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...

# %%
ratings = pd.read_csv('./downloads/the-movies-dataset/ratings_small.csv')
ratings = ratings[['userId','movieId','rating']]
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %%
#  pd.to_numeric 문자열을 숫자로 변환
meta.movieId = pd.to_numeric(meta.movieId, errors='coerce')
ratings.movieId = pd.to_numeric(ratings.movieId, errors='coerce')

# %%
def parse_genres(genres_str):
    genres = json.loads(genres_str.replace('\'','"'))
    
    genres_list = []
    for g in genres:
        genres_list.append(g['name'])
        
    return genres_list

meta['genres'] = meta['genres'].apply(parse_genres)
meta.head()
# Out:
#       movieId original_title original_language                       genres
# 642     54285        삼공일 삼공이                ko  [Horror, Mystery, Thriller]
# 3901    25660    인정사정 볼 것 없다                ko      [Action, Comedy, Crime]
# 5392     8653              섬                ko            [Drama, Thriller]
# 5550    37288       고양이를 부탁해                ko                      [Drama]
# 5683    33251        Jibeuro                ko              [Drama, Family]

# %%
#평가 테이블 ,영화 테이블 합친다
data = pd.merge(ratings, meta, on = 'movieId',how='inner')

data.head()
# Out:
#    userId  movieId  rating original_title original_language  \
# 0      15     1280     3.0             빈집                ko
# 1      23     1280     5.0             빈집                ko
# 2     265     1280     2.0             빈집                ko
# 3     306     1280     4.0             빈집                ko
# 4     388     1280     4.0             빈집                ko
#
#                     genres
# 0  [Drama, Romance, Crime]
# 1  [Drama, Romance, Crime]
# 2  [Drama, Romance, Crime]
# 3  [Drama, Romance, Crime]
# 4  [Drama, Romance, Crime]

# %%
#pivot table
matrix = data.pivot_table(index='userId',columns='original_title',values='rating')

# %%
#pearson 상관관계
GENRE_WEIGHT = 0.1

def pearsonR(s1,s2):
    s1_c = s1-s1.mean()
    s2_c = s2-s2.mean()
    return np.sum(s1_c*s2_c)/np.sqrt(np.sum(s1_c**2)*np.sum(s2_c**2))

# input_movie :영화 타이틀 , matrix :pivot table , n: 추천 받을 영화수 ,  similar_genre: 비슷한 장르에 가중치 유무
def recommend(input_movie, matrix,n,similar_genre=True):
    input_genres = meta[meta['original_title']==input_movie]['genres'].iloc(0)[0]
    
    result = []
    for title in matrix.columns:
        if title == input_movie:
            continue
        # rating comparison
        cor = pearsonR(matrix[input_movie], matrix[title])
        
        # genre comparison
        if similar_genre and len(input_genres) > 0:
            temp_genres = meta[meta['original_title'] == title]['genres'].iloc(0)[0]

            same_count = np.sum(np.isin(input_genres, temp_genres))
            cor += (GENRE_WEIGHT * same_count)
        
        if np.isnan(cor):
            continue
        else:
            result.append((title, '{:.2f}'.format(cor), temp_genres))
    #레이팅 r[1] 이 높은 순서대로 내림차순 정렬       
    result.sort(key=lambda r: r[1], reverse=True)

    return result[:n]

# %%
recommend_result = recommend('The Dark Knight', matrix, 10, similar_genre=True)

pd.DataFrame(recommend_result, columns = ['Title', 'Correlation', 'Genre'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-efbb242bb943> in <module>
# ----> 1 recommend_result = recommend('The Dark Knight', matrix, 10, similar_genre=True)
#       2
#       3 pd.DataFrame(recommend_result, columns = ['Title', 'Correlation', 'Genre'])
#
# <ipython-input-10-e75fd31922ad> in recommend(input_movie, matrix, n, similar_genre)
#       9 # input_movie :영화 타이틀 , matrix :pivot table , n: 추천 받을 영화수 ,  similar_genre: 비슷한 장르에 가중치 유무
#      10 def recommend(input_movie, matrix,n,similar_genre=True):
# ---> 11     input_genres = meta[meta['original_title']==input_movie]['genres'].iloc(0)[0]
#      12
#      13     result = []
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# ...
